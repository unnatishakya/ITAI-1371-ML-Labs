# %% [markdown]
# <a href="https://colab.research.google.com/github/unnatishakya/ITAI-1371-ML-Labs/blob/labs/Module02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import warnings
warnings.filterwarnings('ignore')

print("✅ All libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# ✅ All libraries imported successfully!
# Pandas version: 2.2.2
# NumPy version: 2.0.2

# %%
from sklearn.datasets import load_iris

iris = load_iris()
print("Dataset loaded successfully!")
print(f"Dataset shape: {iris.data.shape}")
print(f"Features: {iris.feature_names}")
print(f"Target classes: {iris.target_names}")
# Out:
# Dataset loaded successfully!
# Dataset shape: (150, 4)
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target classes: ['setosa' 'versicolor' 'virginica']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

print("First 5 rows of our dataset:")
print(df.head())
print("\nDataset info:")
print(df.info())
# Out:
# First 5 rows of our dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 6))
species_colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

for species in df['species'].unique():
    species_data = df[df['species'] == species]
    plt.scatter(species_data['sepal length (cm)'],
                species_data['sepal width (cm)'],
                c=species_colors[species],
                label=species,
                alpha=0.7)

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Iris Dataset: Sepal Length vs Sepal Width')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("🎉 Congratulations! You've created your first data visualization!")
# Out:
# 🎉 Congratulations! You've created your first data visualization!

# %%
print("Basic Statistics for Iris Dataset:")
print("=" * 40)

species_means = df.groupby('species').mean()
print("\nMean values by species:")
print(species_means)

species_counts = df['species'].value_counts()
print("\nSamples per species:")
print(species_counts)
# Out:
# Basic Statistics for Iris Dataset:
# ...
#
# Mean values by species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# Samples per species:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Assessment:

# %%
sepal_lengths = df['sepal length (cm)']

mean_sepal_length = np.mean(sepal_lengths)
std_sepal_length = np.std(sepal_lengths)

print(f"Mean sepal length: {mean_sepal_length:.2f} cm")
print(f"Standard deviation: {std_sepal_length:.2f} cm")

assert isinstance(mean_sepal_length, (float, np.floating)), "Mean should be a number"
assert isinstance(std_sepal_length, (float, np.floating)), "Std should be a number"
print("✅ Task 1 completed successfully!")
# Out:
# Mean sepal length: 5.84 cm
# Standard deviation: 0.83 cm
# ✅ Task 1 completed successfully!

# %%
species_counts = df['species'].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(species_counts.index, species_counts.values, color=['red', 'blue', 'green'])
plt.title('Number of Samples per Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

print(f"Species distribution: {dict(species_counts)}")
print("✅ Task 2 completed successfully!")
# Out:
# Species distribution: {'setosa': np.int64(50), 'versicolor': np.int64(50), 'virginica': np.int64(50)}
# ✅ Task 2 completed successfully!

# %% [markdown]
# ##**Analysis and Reflection**

# %% [markdown]
# ### My Observations About the Iris Dataset
#
# **Dataset Overview:**
# - Number of samples: 150
# - Number of features: 4
# - Number of classes: 3
#
# **Key Findings from the Visualization:**
# 1. Setosa sepal length is under 6 cm but over 3 cm in sepal width. Most of the plots are concentrated around the top left quadrant of the graph indicating the Setosa samples are similar in nature. The samples have shorter sepal length and wider sepal width compared to other classes.
# 2. Versicolor has sepal length between 5 and 7 cm and sepal width under 3.5cm. The plots are more scattered compared to Setosa. It falls between other two classes in terms of sepal width and length.
# 3. Virginica has sepal length above 5.5 cm with some outliers and sepal width between 2 and 3.5 cm. The plots are even more scattered meaning the width and length varies more from one sample to another. It has the longest sepal length but wide range of sepal width compared to others.
#
# **Questions for Further Investigation:**
# - Create a scatter plot comparing petals length and width among the classes.
# - Create a mean and standard deviation of sepal width.
#
# **Reflection:**
# This lab helped me conduct mathematical operations on data and it's visualization through python on Google Colab. It also helped me access the necessary libraries for data.

# %% [markdown]
# # **Further Investigation**

# %% [markdown]
# A scatter plot comparing petals length and width among the classes.

# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

plt.figure(figsize=(10,6))
species_colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

for species in df['species'].unique():
    species_data = df[df['species'] == species]
    plt.scatter(species_data['petal length (cm)'],
                species_data['petal width (cm)'],
                c=species_colors[species],
                label=species,
                alpha=0.7)

plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Dataset: Petal Length vs Petal Width')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# A mean and standard deviation of sepal width

# %%
import numpy as np

sepal_width = df['sepal width (cm)']

mean_sepal_width = np.mean(sepal_width)
std_sepal_width = np.std(sepal_width)

print(f"Mean sepal width: {mean_sepal_width:.2f} cm")
print(f"Standard deviation: {std_sepal_width:.2f} cm")

assert isinstance(mean_sepal_width, (float, np.floating)), "Mean should be a number"
assert isinstance(mean_sepal_width, (float, np.floating)), "Std should be a number"
# Out:
# Mean sepal width: 3.06 cm
# Standard deviation: 0.43 cm
